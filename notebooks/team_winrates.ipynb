# %%
import pandas as pd
import numpy as np
import math

# %%
df_maps = pd.read_csv('../data/maps_scores.csv')

# df_maps.dtypes
df_maps.head()
# Out:
#                               Tournament           Stage Match Type  \
# 0  Champions Tour 2024: Americas Stage 2  Regular Season     Week 1
# 1  Champions Tour 2024: Americas Stage 2  Regular Season     Week 1
# 2  Champions Tour 2024: Americas Stage 2  Regular Season     Week 1
# 3  Champions Tour 2024: Americas Stage 2  Regular Season     Week 1
# 4  Champions Tour 2024: Americas Stage 2  Regular Season     Week 1
#
#                  Match Name     Map     Team A  Team A Score  \
# 0          MIBR vs Leviatán  Ascent       MIBR             9
# 1          MIBR vs Leviatán  Icebox       MIBR             7
# 2  Sentinels vs NRG Esports   Lotus  Sentinels            13
# 3  Sentinels vs NRG Esports  Sunset  Sentinels            14
# 4      FURIA vs 100 Thieves  Icebox      FURIA            14
#
#    Team A Attacker Score  Team A Defender Score  Team A Overtime Score  \
# 0                      6                      3                    NaN
# 1                      3                      4                    NaN
# 2                      8                      5                    NaN
# 3                      9                      3                    2.0
# 4                      6                      6                    2.0
#
#         Team B  Team B Score  Team B Attacker Score  Team B Defender Score  \
# 0     Leviatán            13                      7                      6
# 1     Leviatán            13                      4                      9
# 2  NRG Esports             8                      4                      4
# 3  NRG Esports            12                      9                      3
# 4  100 Thieves            12                      6                      6
#
#    Team B Overtime Score Duration
# 0                    NaN  1:05:24
# 1                    NaN    45:04
# 2                    NaN    59:21
# 3                    0.0  1:00:54
# 4                    0.0  1:12:51

# %%
# df_maps[(df_maps['Team B'] == 'FNATIC') & (df_maps['Map'] == 'Ascent')]

# %%
# Lista de equipos participantes
participating_teams = ['FNATIC', 'Bilibili Gaming', 'DRX', 'KRÜ Esports', 'Gen.G', 'Sentinels', 'FunPlus Phoenix', 'Team Heretics', 'Leviatán', 'Talon Esports', 'Team Vitality', 'Trace Esports', 'EDward Gaming', 'FUT Esports', 'G2 Esports', 'Paper Rex']

# Eliminar columnas innecesarias
df_maps.drop(columns=['Tournament', 'Stage', 'Match Type', 'Match Name', 'Team A Attacker Score', 'Team A Defender Score', 'Team A Overtime Score', 'Team B Attacker Score', 'Team B Defender Score', 'Team B Overtime Score', 'Duration'], inplace=True)

# %%
# Filtrar los datos para mantener solo los de los equipos participantes
filtered_df_maps = df_maps[df_maps['Team A'].isin(participating_teams) | df_maps['Team B'].isin(participating_teams)]
filtered_df_maps
# Out:
#          Map      Team A  Team A Score       Team B  Team B Score
# 0     Ascent        MIBR             9     Leviatán            13
# 1     Icebox        MIBR             7     Leviatán            13
# 2      Lotus   Sentinels            13  NRG Esports             8
# 3     Sunset   Sentinels            14  NRG Esports            12
# 9     Ascent  G2 Esports            13       Cloud9            11
# ...      ...         ...           ...          ...           ...
# 1013   Lotus         DRX             8        Gen.G            13
# 1014  Ascent   Paper Rex             5        Gen.G            13
# 1015   Split   Paper Rex            13        Gen.G             4
# 1016   Lotus   Paper Rex            11        Gen.G            13
# 1017    Bind   Paper Rex             4        Gen.G            13
#
# [742 rows x 5 columns]

# %%
# Crea una columna nueva con el ganador de cada mapa
filtered_df_maps['Map Winner'] = np.where(filtered_df_maps['Team A Score'] > filtered_df_maps['Team B Score'], filtered_df_maps['Team A'], filtered_df_maps['Team B'])
filtered_df_maps.head(3)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13492\3021565895.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_maps['Map Winner'] = np.where(filtered_df_maps['Team A Score'] > filtered_df_maps['Team B Score'], filtered_df_maps['Team A'], filtered_df_maps['Team B'])
#       Map     Team A  Team A Score       Team B  Team B Score Map Winner
# 0  Ascent       MIBR             9     Leviatán            13   Leviatán
# 1  Icebox       MIBR             7     Leviatán            13   Leviatán
# 2   Lotus  Sentinels            13  NRG Esports             8  Sentinels

# %%
# Crear tabla de victorias por mapa por equipo para este año
team_map_wins = filtered_df_maps.groupby(['Map Winner', 'Map']).size().unstack(fill_value=0)
team_map_wins = team_map_wins[team_map_wins.index.isin(participating_teams)]

team_map_wins.reset_index(inplace=True)
team_map_wins.rename(columns={'Map Winner': 'Team'}, inplace=True)

team_map_wins
# Out:
# Map             Team  Abyss  Ascent  Bind  Breeze  Haven  Icebox  Lotus  \
# 0    Bilibili Gaming      0       3     4       0      0       5      5
# 1                DRX      1       5     5       3      4       4      3
# 2      EDward Gaming      1       4     8       6      2       4      2
# 3             FNATIC      0       3     5       5      5       2     11
# 4        FUT Esports      0       4     4       1      0       4      6
# 5    FunPlus Phoenix      2       6     3       3      3       6     10
# 6         G2 Esports      1       7     8       3      1       6     10
# 7              Gen.G      0      14     8       8      2      10     16
# 8        KRÜ Esports      1       2     0       3      2       3      5
# 9           Leviatán      1       4     5       3      2      12      6
# 10         Paper Rex      1       5     6       0      0       6      8
# 11         Sentinels      0       2     4       0      1       3     10
# 12     Talon Esports      1       2     3       3      0       2      7
# 13     Team Heretics      1       1    10       2      2       9     10
# 14     Team Vitality      0       3     1       4      1       5      5
# 15     Trace Esports      0       5     3       2      4       0      8
#
# Map  Split  Sunset
# 0        1       3
# 1        3       2
# 2        6       8
# 3        4       3
# 4        6       5
# 5        0       6
# 6        5       2
# 7        7       5
# 8        4       3
# 9        0       7
# 10       7      15
# 11      12       6
# 12       0       1
# 13       5      15
# 14       0       9
# 15       3       8

# %%
# Crear tabla de cantidad de veces que se jugo cada mapa por equipo

team_map_counts = df_maps.groupby(['Team A', 'Map']).size().unstack(fill_value=0)
team_map_counts += df_maps.groupby(['Team B', 'Map']).size().unstack(fill_value=0)
team_map_counts = team_map_counts.loc[participating_teams]

team_map_counts.reset_index(inplace=True)
team_map_counts.rename(columns={'Map Winner': 'Team'}, inplace=True)

team_map_counts
# Out:
# Map           Team A  Abyss  Ascent  Bind  Breeze  Haven  Icebox  Lotus  \
# 0             FNATIC      0       6     9       8      5       7     16
# 1    Bilibili Gaming      0       5     8       1      1       9      9
# 2                DRX      2       9     9       4      5       6      7
# 3        KRÜ Esports      2       8     0       4      2       9      8
# 4              Gen.G      0      17    12      12      3      16     21
# 5          Sentinels      0       6     8       4      2       7     13
# 6    FunPlus Phoenix      2      11     6       7      7      11     15
# 7      Team Heretics      1       2    13       5      3      13     18
# 8           Leviatán      1       7    10       6      3      15      9
# 9      Talon Esports      2       9     3       4      2       5     10
# 10     Team Vitality      0       6     3       5      4       9     12
# 11     Trace Esports      2       5     9       5      7       0     11
# 12     EDward Gaming      2       7    13       8      3       9      4
# 13       FUT Esports      1       4     9       2      1       8     11
# 14        G2 Esports      1      10    13       6      2      14     16
# 15         Paper Rex      1      12    12       2      1      10     16
#
# Map  Split  Sunset
# 0        6       4
# 1        2       6
# 2        5       5
# 3        7       8
# 4       14      10
# 5       16       8
# 6        1      12
# 7       12      19
# 8        3      10
# 9        1       5
# 10       1      14
# 11       5      14
# 12       8      12
# 13      10      12
# 14       8       6
# 15       9      17

# %% [markdown]
# ## Lista de Winrates por equipo por mapa

# %%
# Calcular el porcentaje de victorias por mapa por equipo
team_map_win_rates = ((team_map_wins.set_index('Team') / team_map_counts.set_index('Team A')) * 100).round(2)
team_map_win_rates.fillna(0, inplace=True)
# team_map_win_rates = team_map_win_rates.astype(str) + '%'
team_map_win_rates.reset_index(inplace=True)
team_map_win_rates
# Out:
# Map            index  Abyss  Ascent    Bind  Breeze   Haven  Icebox  Lotus  \
# 0    Bilibili Gaming    0.0   60.00   50.00    0.00    0.00   55.56  55.56
# 1                DRX   50.0   55.56   55.56   75.00   80.00   66.67  42.86
# 2      EDward Gaming   50.0   57.14   61.54   75.00   66.67   44.44  50.00
# 3             FNATIC    0.0   50.00   55.56   62.50  100.00   28.57  68.75
# 4        FUT Esports    0.0  100.00   44.44   50.00    0.00   50.00  54.55
# 5    FunPlus Phoenix  100.0   54.55   50.00   42.86   42.86   54.55  66.67
# 6         G2 Esports  100.0   70.00   61.54   50.00   50.00   42.86  62.50
# 7              Gen.G    0.0   82.35   66.67   66.67   66.67   62.50  76.19
# 8        KRÜ Esports   50.0   25.00    0.00   75.00  100.00   33.33  62.50
# 9           Leviatán  100.0   57.14   50.00   50.00   66.67   80.00  66.67
# 10         Paper Rex  100.0   41.67   50.00    0.00    0.00   60.00  50.00
# 11         Sentinels    0.0   33.33   50.00    0.00   50.00   42.86  76.92
# 12     Talon Esports   50.0   22.22  100.00   75.00    0.00   40.00  70.00
# 13     Team Heretics  100.0   50.00   76.92   40.00   66.67   69.23  55.56
# 14     Team Vitality    0.0   50.00   33.33   80.00   25.00   55.56  41.67
# 15     Trace Esports    0.0  100.00   33.33   40.00   57.14    0.00  72.73
#
# Map  Split  Sunset
# 0    50.00   50.00
# 1    60.00   40.00
# 2    75.00   66.67
# 3    66.67   75.00
# 4    60.00   41.67
# 5     0.00   50.00
# 6    62.50   33.33
# 7    50.00   50.00
# 8    57.14   37.50
# 9     0.00   70.00
# 10   77.78   88.24
# 11   75.00   75.00
# 12    0.00   20.00
# 13   41.67   78.95
# 14    0.00   64.29
# 15   60.00   57.14

# %%
# team_map_win_rates.to_csv('../data/team_map_win_rates.csv')

# %% [markdown]
# ----------------------

# %%
# df_ascent = pd.DataFrame(columns=['Team','Times Played', 'Maps Won', 'Maps Lost', 'Map Win Rate', 'Rounds Won', 'Rounds Lost', 'Avg Round Win', 'Avg Round Loss', 'Map Pick Rate', 'Map Ban Rate'])

# %%
df_ascent = pd.DataFrame()

df_ascent['Team'] = participating_teams
df_ascent['Times Played'] = team_map_counts['Ascent']
df_ascent['Maps Won'] = df_ascent['Team'].map(team_map_wins.set_index('Team')['Ascent'])
df_ascent['Maps Lost'] = df_ascent['Times Played'] - df_ascent['Maps Won']
df_ascent['Map Win Rate (%)'] = df_ascent['Team'].map(team_map_win_rates.set_index('index')['Ascent'])

for team in df_ascent['Team']:
    sum_team_score = df_maps.loc[(df_maps['Map'] == 'Ascent') & (df_maps['Team A'] == team), 'Team A Score'].sum()
    sum_team_score += df_maps.loc[(df_maps['Map'] == 'Ascent') & (df_maps['Team B'] == team), 'Team B Score'].sum()
    df_ascent.loc[df_ascent['Team'] == team, 'Rounds Won'] = sum_team_score
    df_ascent['Rounds Won'] = df_ascent['Rounds Won'].astype(int, errors='ignore')

    sum_team_rounds = df_maps.loc[(df_maps['Map'] == 'Ascent') & (df_maps['Team A'] == team), 'Team B Score'].sum()
    sum_team_rounds += df_maps.loc[(df_maps['Map'] == 'Ascent') & (df_maps['Team B'] == team), 'Team A Score'].sum()
    df_ascent.loc[df_ascent['Team'] == team, 'Rounds Lost'] = sum_team_rounds
    df_ascent['Rounds Lost'] = df_ascent['Rounds Lost'].astype(int, errors='ignore')

df_ascent['Avg Round Win (Per Game)'] = (df_ascent['Rounds Won'] / (df_ascent['Times Played'])).round(2)
df_ascent['Avg Round Loss (Per Game)'] = (df_ascent['Rounds Lost'] / (df_ascent['Times Played'])).round(2)

df_ascent
# Out:
#                Team  Times Played  Maps Won  Maps Lost  Map Win Rate (%)  \
# 0            FNATIC             6         3          3             50.00
# 1   Bilibili Gaming             5         3          2             60.00
# 2               DRX             9         5          4             55.56
# 3       KRÜ Esports             8         2          6             25.00
# 4             Gen.G            17        14          3             82.35
# 5         Sentinels             6         2          4             33.33
# 6   FunPlus Phoenix            11         6          5             54.55
# 7     Team Heretics             2         1          1             50.00
# 8          Leviatán             7         4          3             57.14
# 9     Talon Esports             9         2          7             22.22
# 10    Team Vitality             6         3          3             50.00
# 11    Trace Esports             5         5          0            100.00
# 12    EDward Gaming             7         4          3             57.14
# 13      FUT Esports             4         4          0            100.00
# 14       G2 Esports            10         7          3             70.00
# 15        Paper Rex            12         5          7             41.67
#
#     Rounds Won  Rounds Lost  Avg Round Win (Per Game)  \
# 0           59           64                      9.83
# 1           51           51                     10.20
# 2           99           93                     11.00
# 3           81          100                     10.12
# 4          212          151                     12.47
# 5           61           64                     10.17
# 6          118          106                     10.73
# 7           24           22                     12.00
# 8           86           71                     12.29
# 9           76          105                      8.44
# 10          64           64                     10.67
# 11          65           33                     13.00
# 12          71           66                     10.14
# 13          53           33                     13.25
# 14         115          118                     11.50
# 15         120          128                     10.00
#
#     Avg Round Loss (Per Game)
# 0                       10.67
# 1                       10.20
# 2                       10.33
# 3                       12.50
# 4                        8.88
# 5                       10.67
# 6                        9.64
# 7                       11.00
# 8                       10.14
# 9                       11.67
# 10                      10.67
# 11                       6.60
# 12                       9.43
# 13                       8.25
# 14                      11.80
# 15                      10.67

# %%
# Assuming you want to print the rows where the 'Team' column in df_ascent equals 'FNATIC'
# df_maps[(df_maps['Team B'] == 'FNATIC') & (df_maps['Map'] == 'Ascent')]

# %%
# df_maps

team = 'FNATIC'
map_name = 'Ascent'

sum_team_score = df_maps.loc[(df_maps['Map'] == map_name) & (df_maps['Team A'] == team), 'Team A Score'].sum()
print(sum_team_score)
sum_team_score += df_maps.loc[(df_maps['Map'] == map_name) & (df_maps['Team B'] == team), 'Team B Score'].sum()
print(sum_team_score)

df_ascent['Rounds Won'] = sum_team_score
df_ascent
# Out:
# 22
# 59
#                Team  Times Played  Maps Won  Maps Lost  Map Win Rate (%)  \
# 0            FNATIC             6         3          3             50.00
# 1   Bilibili Gaming             5         3          2             60.00
# 2               DRX             9         5          4             55.56
# 3       KRÜ Esports             8         2          6             25.00
# 4             Gen.G            17        14          3             82.35
# 5         Sentinels             6         2          4             33.33
# 6   FunPlus Phoenix            11         6          5             54.55
# 7     Team Heretics             2         1          1             50.00
# 8          Leviatán             7         4          3             57.14
# 9     Talon Esports             9         2          7             22.22
# 10    Team Vitality             6         3          3             50.00
# 11    Trace Esports             5         5          0            100.00
# 12    EDward Gaming             7         4          3             57.14
# 13      FUT Esports             4         4          0            100.00
# 14       G2 Esports            10         7          3             70.00
# 15        Paper Rex            12         5          7             41.67
#
#     Rounds Won  Rounds Lost  Avg Round Win (%)
# 0           59           64              47.97
# 1           59           51              50.00
# 2           59           93              51.56
# 3           59          100              44.75
# 4           59          151              58.40
# 5           59           64              48.80
# 6           59          106              52.68
# 7           59           22              52.17
# 8           59           71              54.78
# 9           59          105              41.99
# 10          59           64              50.00
# 11          59           33              66.33
# 12          59           66              51.82
# 13          59           33              61.63
# 14          59          118              49.36
# 15          59          128              48.39
